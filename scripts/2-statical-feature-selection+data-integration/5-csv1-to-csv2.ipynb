# %% [markdown]
# # <center> libraries </center>

# %%
import pandas as pd

# %% [markdown]
# # <center> csv files path </center>

# %%
# ddos

ddos_conn_fp  = {}
ddos_dns_fp   = {}
ddos_http_fp  = {}
ddos_ssl_fp   = {}
ddos_weird_fp = {}

for i in range(1, 13):
    ddos_conn_fp[i]  = f'your-path\\normal-attack\\csv-1\\DDoS\\{i}\\conn.csv'
    ddos_dns_fp[i]   = f'your-path\\normal-attack\\csv-1\\DDoS\\{i}\\dns.csv'
    ddos_http_fp[i]  = f'your-path\\normal-attack\\csv-1\\DDoS\\{i}\\http.csv'
    ddos_ssl_fp[i]   = f'your-path\\normal-attack\\csv-1\\DDoS\\{i}\\ssl.csv'
    ddos_weird_fp[i] = f'your-path\\normal-attack\\csv-1\\DDoS\\{i}\\weird.csv'

# %%
# backdoor

backdoor_conn_fp  = f'your-path\\normal-attack\\csv-1\\backdoor\\1\\conn.csv'
backdoor_dns_fp   = f'your-path\\normal-attack\\csv-1\\backdoor\\1\\dns.csv'
backdoor_http_fp  = f'your-path\\normal-attack\\csv-1\\backdoor\\1\\http.csv'
backdoor_ssl_fp   = f'your-path\\normal-attack\\csv-1\\backdoor\\1\\ssl.csv'
backdoor_weird_fp = f'your-path\\normal-attack\\csv-1\\backdoor\\1\\weird.csv'

# %%
# dos

dos_conn_fp  = {}
dos_dns_fp   = {}
dos_http_fp  = {}
dos_ssl_fp   = {}
dos_weird_fp = {}

for i in range(1, 6):
    dos_conn_fp[i]  = f'your-path\\normal-attack\\csv-1\\DoS\\{i}\\conn.csv'
    dos_dns_fp[i]   = f'your-path\\normal-attack\\csv-1\\DoS\\{i}\\dns.csv'
    dos_http_fp[i]  = f'your-path\\normal-attack\\csv-1\\DoS\\{i}\\http.csv'
    dos_ssl_fp[i]   = f'your-path\\normal-attack\\csv-1\\DoS\\{i}\\ssl.csv'
    dos_weird_fp[i] = f'your-path\\normal-attack\\csv-1\\DoS\\{i}\\weird.csv'

# %%
# injection

injection_conn_fp  = {}
injection_dns_fp   = {}
injection_http_fp  = {}
injection_ssl_fp   = {}
injection_weird_fp = {}

for i in range(1, 5):
    injection_conn_fp[i]  = f'your-path\\normal-attack\\csv-1\\Injection\\{i}\\conn.csv'
    injection_dns_fp[i]   = f'your-path\\normal-attack\\csv-1\\Injection\\{i}\\dns.csv'
    injection_http_fp[i]  = f'your-path\\normal-attack\\csv-1\\Injection\\{i}\\http.csv'
    injection_ssl_fp[i]   = f'your-path\\normal-attack\\csv-1\\Injection\\{i}\\ssl.csv'
    injection_weird_fp[i] = f'your-path\\normal-attack\\csv-1\\Injection\\{i}\\weird.csv'

# %%
# MITM

mitm_conn_fp  = {}
mitm_dns_fp   = {}
mitm_http_fp  = {}
mitm_ssl_fp   = {}
mitm_weird_fp = {}

for i in range(1, 5):
    mitm_conn_fp[i]  = f'your-path\\normal-attack\\csv-1\\MITM\\{i}\\conn.csv'
    mitm_dns_fp[i]   = f'your-path\\normal-attack\\csv-1\\MITM\\{i}\\dns.csv'
    mitm_http_fp[i]  = f'your-path\\normal-attack\\csv-1\\MITM\\{i}\\http.csv'
    mitm_ssl_fp[i]   = f'your-path\\normal-attack\\csv-1\\MITM\\{i}\\ssl.csv'
    mitm_weird_fp[i] = f'your-path\\normal-attack\\csv-1\\MITM\\{i}\\weird.csv'

# %%
# normal

normal_conn_fp  = {}
normal_dns_fp   = {}
normal_http_fp  = {}
normal_ssl_fp   = {}
normal_weird_fp = {}

for i in range(1, 16):
    normal_conn_fp[i]  = f'your-path\\normal\\csv-1\\{i}\\conn.csv'
    normal_dns_fp[i]   = f'your-path\\normal\\csv-1\\{i}\\dns.csv'
    normal_http_fp[i]  = f'your-path\\normal\\csv-1\\{i}\\http.csv'
    normal_ssl_fp[i]   = f'your-path\\normal\\csv-1\\{i}\\ssl.csv'
    normal_weird_fp[i] = f'your-path\\normal\\csv-1\\{i}\\weird.csv'

# %%
# password

password_conn_fp  = {}
password_dns_fp   = {}
password_http_fp  = {}
password_ssl_fp   = {}
password_weird_fp = {}

for i in range(1, 6):
    password_conn_fp[i]  = f'your-path\\normal-attack\\csv-1\\password\\{i}\\conn.csv'
    password_dns_fp[i]   = f'your-path\\normal-attack\\csv-1\\password\\{i}\\dns.csv'
    password_http_fp[i]  = f'your-path\\normal-attack\\csv-1\\password\\{i}\\http.csv'
    password_ssl_fp[i]   = f'your-path\\normal-attack\\csv-1\\password\\{i}\\ssl.csv'
    password_weird_fp[i] = f'your-path\\normal-attack\\csv-1\\password\\{i}\\weird.csv'

# %%
# ransomware

ransomware_conn_fp  = f'your-path\\normal-attack\\csv-1\\runsomware\\1\\conn.csv'
ransomware_dns_fp   = f'your-path\\normal-attack\\csv-1\\runsomware\\1\\dns.csv'
ransomware_http_fp  = f'your-path\\normal-attack\\csv-1\\runsomware\\1\\http.csv'
ransomware_ssl_fp   = f'your-path\\normal-attack\\csv-1\\runsomware\\1\\ssl.csv'
ransomware_weird_fp = f'your-path\\normal-attack\\csv-1\\runsomware\\1\\weird.csv'

# %%
# scanning

scanning_conn_fp  = {}
scanning_dns_fp   = {}
scanning_http_fp  = {}
scanning_ssl_fp   = {}
scanning_weird_fp = {}

for i in range(1, 7):
    scanning_conn_fp[i]  = f'your-path\\normal-attack\\csv-1\\scanning\\{i}\\conn.csv'
    scanning_dns_fp[i]   = f'your-path\\normal-attack\\csv-1\\scanning\\{i}\\dns.csv'
    scanning_http_fp[i]  = f'your-path\\normal-attack\\csv-1\\scanning\\{i}\\http.csv'
    scanning_ssl_fp[i]   = f'your-path\\normal-attack\\csv-1\\scanning\\{i}\\ssl.csv'
    scanning_weird_fp[i] = f'your-path\\normal-attack\\csv-1\\scanning\\{i}\\weird.csv'

# %%
# xss

xss_conn_fp  = {}
xss_dns_fp   = {}
xss_http_fp  = {}
xss_ssl_fp   = {}
xss_weird_fp = {}

for i in range(1, 11):
    xss_conn_fp[i]  = f'your-path\\normal-attack\\csv-1\\XSS\\{i}\\conn.csv'
    xss_dns_fp[i]   = f'your-path\\normal-attack\\csv-1\\XSS\\{i}\\dns.csv'
    xss_http_fp[i]  = f'your-path\\normal-attack\\csv-1\\XSS\\{i}\\http.csv'
    xss_ssl_fp[i]   = f'your-path\\normal-attack\\csv-1\\XSS\\{i}\\ssl.csv'
    xss_weird_fp[i] = f'your-path\\normal-attack\\csv-1\\XSS\\{i}\\weird.csv'

# %% [markdown]
# # <center> create dataframes </center>

# %%
# ddos

ddos_conn_df  = {}
ddos_dns_df   = {}
ddos_http_df  = {}
ddos_ssl_df   = {}
ddos_weird_df = {}

for i in range(1, 13):
    ddos_conn_df[i]  = pd.read_csv(ddos_conn_fp[i], on_bad_lines="error")
    ddos_dns_df[i]   = pd.read_csv(ddos_dns_fp[i], on_bad_lines="error")
    ddos_http_df[i]  = pd.read_csv(ddos_http_fp[i], on_bad_lines="error")
    ddos_ssl_df[i]   = pd.read_csv(ddos_ssl_fp[i], on_bad_lines="error")
    ddos_weird_df[i] = pd.read_csv(ddos_weird_fp[i], on_bad_lines="error")

# %%
# backdoor

backdoor_conn_df  = pd.read_csv(backdoor_conn_fp, on_bad_lines="error")
backdoor_dns_df   = pd.read_csv(backdoor_dns_fp, on_bad_lines="error")
backdoor_http_df  = pd.read_csv(backdoor_http_fp, on_bad_lines="error")
backdoor_ssl_df   = pd.read_csv(backdoor_ssl_fp, on_bad_lines="error")
backdoor_weird_df = pd.read_csv(backdoor_weird_fp, on_bad_lines="error")

# %%
# password

password_conn_df  = {}
password_dns_df   = {}
password_http_df  = {}
password_ssl_df   = {}
password_weird_df = {}

for i in range(1, 6):
    password_conn_df[i]  = pd.read_csv(password_conn_fp[i], on_bad_lines="error")
    password_dns_df[i]   = pd.read_csv(password_dns_fp[i], on_bad_lines="error")
    password_http_df[i]  = pd.read_csv(password_http_fp[i], on_bad_lines="error")
    password_ssl_df[i]   = pd.read_csv(password_ssl_fp[i], on_bad_lines="error")
    password_weird_df[i] = pd.read_csv(password_weird_fp[i], on_bad_lines="error")

# %%
# ransomware

ransomware_conn_df  = pd.read_csv(ransomware_conn_fp, on_bad_lines="error")
ransomware_dns_df   = pd.read_csv(ransomware_dns_fp, on_bad_lines="error")
ransomware_http_df  = pd.read_csv(ransomware_http_fp, on_bad_lines="error")
ransomware_ssl_df   = pd.read_csv(ransomware_ssl_fp, on_bad_lines="error")
ransomware_weird_df = pd.read_csv(ransomware_weird_fp, on_bad_lines="error")

# %%
# injection

injection_conn_df  = {}
injection_dns_df   = {}
injection_http_df  = {}
injection_ssl_df   = {}
injection_weird_df = {}

for i in range(1, 5):
    injection_conn_df[i]  = pd.read_csv(injection_conn_fp[i], on_bad_lines="error")
    injection_dns_df[i]   = pd.read_csv(injection_dns_fp[i], on_bad_lines="error")
    injection_http_df[i]  = pd.read_csv(injection_http_fp[i], on_bad_lines="error")
    injection_ssl_df[i]   = pd.read_csv(injection_ssl_fp[i], on_bad_lines="error")
    injection_weird_df[i] = pd.read_csv(injection_weird_fp[i], on_bad_lines="error")

# %%
# scanning

scanning_conn_df  = {}
scanning_dns_df   = {}
scanning_http_df  = {}
scanning_ssl_df   = {}
scanning_weird_df = {}

for i in range(1, 7):
    scanning_conn_df[i]  = pd.read_csv(scanning_conn_fp[i], on_bad_lines="error")
    scanning_dns_df[i]   = pd.read_csv(scanning_dns_fp[i], on_bad_lines="error")
    scanning_http_df[i]  = pd.read_csv(scanning_http_fp[i], on_bad_lines="error")
    scanning_ssl_df[i]   = pd.read_csv(scanning_ssl_fp[i], on_bad_lines="error")
    scanning_weird_df[i] = pd.read_csv(scanning_weird_fp[i], on_bad_lines="error")

# %%
# dos

dos_conn_df  = {}
dos_dns_df   = {}
dos_http_df  = {}
dos_ssl_df   = {}
dos_weird_df = {}

for i in range(1, 6):
    dos_conn_df[i]  = pd.read_csv(dos_conn_fp[i], on_bad_lines="error", low_memory=False)
    dos_dns_df[i]   = pd.read_csv(dos_dns_fp[i], on_bad_lines="error")
    dos_http_df[i]  = pd.read_csv(dos_http_fp[i], on_bad_lines="error")
    dos_ssl_df[i]   = pd.read_csv(dos_ssl_fp[i], on_bad_lines="error")
    dos_weird_df[i] = pd.read_csv(dos_weird_fp[i], on_bad_lines="error")

# %%
# mitm

mitm_conn_df  = {}
mitm_dns_df   = {}
mitm_http_df  = {}
mitm_ssl_df   = {}
mitm_weird_df = {}

for i in range(1, 5):
    mitm_conn_df[i]  = pd.read_csv(mitm_conn_fp[i], on_bad_lines="error")
    mitm_dns_df[i]   = pd.read_csv(mitm_dns_fp[i], on_bad_lines="error", low_memory=False)
    mitm_http_df[i]  = pd.read_csv(mitm_http_fp[i], on_bad_lines="error")
    mitm_ssl_df[i]   = pd.read_csv(mitm_ssl_fp[i], on_bad_lines="error")
    mitm_weird_df[i] = pd.read_csv(mitm_weird_fp[i], on_bad_lines="error")

# %%
# xss

xss_conn_df  = {}
xss_dns_df   = {}
xss_http_df  = {}
xss_ssl_df   = {}
xss_weird_df = {}

for i in range(1, 11):
    xss_conn_df[i]  = pd.read_csv(xss_conn_fp[i], on_bad_lines="error")
    xss_dns_df[i]   = pd.read_csv(xss_dns_fp[i], on_bad_lines="error")
    xss_http_df[i]  = pd.read_csv(xss_http_fp[i], on_bad_lines="error")
    xss_ssl_df[i]   = pd.read_csv(xss_ssl_fp[i], on_bad_lines="error")
    xss_weird_df[i] = pd.read_csv(xss_weird_fp[i], on_bad_lines="error")

# %%
# normal

normal_conn_df  = {}
normal_dns_df   = {}
normal_http_df  = {}
normal_ssl_df   = {}
normal_weird_df = {}

for i in range(1, 16):
    normal_conn_df[i]  = pd.read_csv(normal_conn_fp[i], on_bad_lines="error")
    normal_dns_df[i]   = pd.read_csv(normal_dns_fp[i], on_bad_lines="error")
    normal_http_df[i]  = pd.read_csv(normal_http_fp[i], on_bad_lines="error")
    normal_ssl_df[i]   = pd.read_csv(normal_ssl_fp[i], on_bad_lines="error")
    normal_weird_df[i] = pd.read_csv(normal_weird_fp[i], on_bad_lines="error")

# %% [markdown]
# # <center> add feature </center>

# %%
def ensure_columns(df, columns):
    for column in columns:
        if column not in df.columns:
            df[column] = '-'
    return df

# %% [markdown]
# # <center> select features </center>

# %%
#ddos

ddos_dns_fs   = {}
ddos_http_fs  = {}
ddos_ssl_fs   = {}
ddos_weird_fs = {}

for i in range(1, 13):
    ddos_dns_fs[i]   = ddos_dns_df[i][["uid", "query", "qclass", "qtype", "rcode", "AA", "RD", "RA", "rejected"]]
    ddos_http_fs[i]  = ddos_http_df[i][["uid", "trans_depth", "method", "uri", "referrer", "version", "request_body_len", "response_body_len", "status_code", "user_agent", "orig_mime_types", "resp_mime_types"]]
    ddos_weird_fs[i] = ddos_weird_df[i][["uid", "name", "addl", "notice"]]
    ddos_ssl_df[i]   = ensure_columns(ddos_ssl_df[i], ['subject', 'issuer'])
    ddos_ssl_fs[i]   = ddos_ssl_df[i][["uid", "version", "cipher", "resumed", "established", "subject", "issuer"]]

# %%
# backdoor

backdoor_dns_fs   = backdoor_dns_df[["uid", "query", "qclass", "qtype", "rcode", "AA", "RD", "RA", "rejected"]]
backdoor_http_fs  = backdoor_http_df[["uid", "trans_depth", "method", "uri", "version", "referrer", "request_body_len", "response_body_len", "status_code", "user_agent", "orig_mime_types", "resp_mime_types"]]
backdoor_weird_fs = backdoor_weird_df[["uid", "name", "addl", "notice"]]
backdoor_ssl_df   = ensure_columns(backdoor_ssl_df, ['subject', 'issuer'])
backdoor_ssl_fs   = backdoor_ssl_df[["uid", "version", "cipher", "resumed", "established", "subject", "issuer"]]

# %%
# password

password_dns_fs   = {}
password_http_fs  = {}
password_ssl_fs   = {}
password_weird_fs = {}

for i in range(1, 6):
    password_dns_fs[i]   = password_dns_df[i][["uid", "query", "qclass", "qtype", "rcode", "AA", "RD", "RA", "rejected"]]
    password_http_fs[i]  = password_http_df[i][["uid", "trans_depth", "method", "uri", "referrer", "version", "request_body_len", "response_body_len", "status_code", "user_agent", "orig_mime_types", "resp_mime_types"]]
    password_weird_fs[i] = password_weird_df[i][["uid", "name", "addl", "notice"]]
    password_ssl_df[i]   = ensure_columns(password_ssl_df[i], ['subject', 'issuer'])
    password_ssl_fs[i]   = password_ssl_df[i][["uid", "version", "cipher", "resumed", "established", "subject", "issuer"]]

# %%
# ransomware

ransomware_dns_fs   = ransomware_dns_df[["uid", "query", "qclass", "qtype", "rcode", "AA", "RD", "RA", "rejected"]]
ransomware_http_fs  = ransomware_http_df[["uid", "trans_depth", "method", "uri", "referrer", "version", "request_body_len", "response_body_len", "status_code", "user_agent", "orig_mime_types", "resp_mime_types"]]
ransomware_weird_fs = ransomware_weird_df[["uid", "name", "addl", "notice"]]
ransomware_ssl_df   = ensure_columns(ransomware_ssl_df, ['subject', 'issuer'])
ransomware_ssl_fs   = ransomware_ssl_df[["uid", "version", "cipher", "resumed", "established", "subject", "issuer"]]

# %%
# injection

injection_dns_fs   = {}
injection_http_fs  = {}
injection_ssl_fs   = {}
injection_weird_fs = {}

for i in range(1, 5):
    injection_dns_fs[i]   = injection_dns_df[i][["uid", "query", "qclass", "qtype", "rcode", "AA", "RD", "RA", "rejected"]]
    injection_http_fs[i]  = injection_http_df[i][["uid", "trans_depth", "method", "uri", "referrer", "version", "request_body_len", "response_body_len", "status_code", "user_agent", "orig_mime_types", "resp_mime_types"]]
    injection_weird_fs[i] = injection_weird_df[i][["uid", "name", "addl", "notice"]]
    injection_ssl_df[i]   = ensure_columns(injection_ssl_df[i], ['subject', 'issuer'])
    injection_ssl_fs[i]   = injection_ssl_df[i][["uid", "version", "cipher", "resumed", "established", "subject", "issuer"]]

# %%
# scanning

scanning_dns_fs   = {}
scanning_http_fs  = {}
scanning_ssl_fs   = {}
scanning_weird_fs = {}

for i in range(1, 7):
    scanning_dns_fs[i]   = scanning_dns_df[i][["uid", "query", "qclass", "qtype", "rcode", "AA", "RD", "RA", "rejected"]]
    scanning_http_fs[i]  = scanning_http_df[i][["uid", "trans_depth", "method", "uri", "referrer", "version", "request_body_len", "response_body_len", "status_code", "user_agent", "orig_mime_types", "resp_mime_types"]]
    scanning_weird_fs[i] = scanning_weird_df[i][["uid", "name", "addl", "notice"]]
    scanning_ssl_df[i]   = ensure_columns(scanning_ssl_df[i], ['subject', 'issuer'])
    scanning_ssl_fs[i]   = scanning_ssl_df[i][["uid", "version", "cipher", "resumed", "established", "subject", "issuer"]]

# %%
# dos

dos_dns_fs   = {}
dos_http_fs  = {}
dos_ssl_fs   = {}
dos_weird_fs = {}

for i in range(1, 6):
    dos_dns_fs[i]   = dos_dns_df[i][["uid", "query", "qclass", "qtype", "rcode", "AA", "RD", "RA", "rejected"]]
    dos_http_fs[i]  = dos_http_df[i][["uid", "trans_depth", "method", "uri", "referrer", "version", "request_body_len", "response_body_len", "status_code", "user_agent", "orig_mime_types", "resp_mime_types"]]
    dos_weird_fs[i] = dos_weird_df[i][["uid", "name", "addl", "notice"]]
    dos_ssl_df[i]   = ensure_columns(dos_ssl_df[i], ['subject', 'issuer'])
    dos_ssl_fs[i]   = dos_ssl_df[i][["uid", "version", "cipher", "resumed", "established", "subject", "issuer"]]

# %%
# mitm

mitm_dns_fs   = {}
mitm_http_fs  = {}
mitm_ssl_fs   = {}
mitm_weird_fs = {}

for i in range(1, 5):
    mitm_dns_fs[i]   = mitm_dns_df[i][["uid", "query", "qclass", "qtype", "rcode", "AA", "RD", "RA", "rejected"]]
    mitm_http_fs[i]  = mitm_http_df[i][["uid", "trans_depth", "method", "uri", "referrer", "version", "request_body_len", "response_body_len", "status_code", "user_agent", "orig_mime_types", "resp_mime_types"]]
    mitm_weird_fs[i] = mitm_weird_df[i][["uid", "name", "addl", "notice"]]
    mitm_ssl_df[i]   = ensure_columns(mitm_ssl_df[i], ['subject', 'issuer'])
    mitm_ssl_fs[i]   = mitm_ssl_df[i][["uid", "version", "cipher", "resumed", "established", "subject", "issuer"]]

# %%
# xss

xss_dns_fs   = {}
xss_http_fs  = {}
xss_ssl_fs   = {}
xss_weird_fs = {}

for i in range(1, 11):
    xss_dns_fs[i]   = xss_dns_df[i][["uid", "query", "qclass", "qtype", "rcode", "AA", "RD", "RA", "rejected"]]
    xss_http_fs[i]  = xss_http_df[i][["uid", "trans_depth", "method", "uri", "referrer", "version", "request_body_len", "response_body_len", "status_code", "user_agent", "orig_mime_types", "resp_mime_types"]]
    xss_weird_fs[i] = xss_weird_df[i][["uid", "name", "addl", "notice"]]
    xss_ssl_df[i]   = ensure_columns(xss_ssl_df[i], ['subject', 'issuer'])
    xss_ssl_fs[i]   = xss_ssl_df[i][["uid", "version", "cipher", "resumed", "established", "subject", "issuer"]]

# %%
# normal

normal_dns_fs   = {}
normal_http_fs  = {}
normal_ssl_fs   = {}
normal_weird_fs = {}

for i in range(1, 16):
    normal_dns_fs[i]   = normal_dns_df[i][["uid", "query", "qclass", "qtype", "rcode", "AA", "RD", "RA", "rejected"]]
    normal_http_fs[i]  = normal_http_df[i][["uid", "trans_depth", "method", "uri", "referrer", "version", "request_body_len", "response_body_len", "status_code", "user_agent", "orig_mime_types", "resp_mime_types"]]
    normal_weird_fs[i] = normal_weird_df[i][["uid", "name", "addl", "notice"]]
    normal_ssl_df[i]   = ensure_columns(normal_ssl_df[i], ['subject', 'issuer'])
    normal_ssl_fs[i]   = normal_ssl_df[i][["uid", "version", "cipher", "resumed", "established", "subject", "issuer"]]

# %% [markdown]
# # <center> rename features </center>

# %%
# ddos

new_conn_column_names = {
    'id.orig_h': 'src_ip',
    'id.orig_p': 'src_port',
    'id.resp_h': 'dst_ip',
    'id.resp_p': 'dst_port',
    'orig_bytes': 'src_bytes',
    'resp_bytes': 'dst_bytes'
}

new_statics_column_names = {
    'orig_pkts': 'src_pkts',
    'resp_pkts': 'dst_pkts',
    'orig_ip_bytes': 'src_ip_bytes',
    'resp_ip_bytes': 'dst_ip_bytes'
}

new_dns_column_names = {
    'query': 'dns_query',
    'qclass': 'dns_qclass',
    'qtype': 'dns_qtype',
    'rcode': 'dns_rcode',
    'AA': 'dns_AA',
    'RD': 'dns_RD',
    'RA': 'dns_RA',
    'rejected': 'dns_rejected'
}

new_ssl_column_names = {
    'version': 'ssl_version',
    'cipher': 'ssl_cipher',
    'resumed': 'ssl_resumed',
    'established': 'ssl_established',
    'subject': 'ssl_subject',
    'issuer': 'ssl_issuer'
}

new_http_column_names = {
    'trans_depth': 'http_trans_depth',
    'method': 'http_method',
    'uri': 'http_uri',
    'referrer': 'http_referrer',
    'version': 'http_version',
    'request_body_len': 'http_request_body_len',
    'response_body_len': 'http_response_body_len',
    'status_code': 'http_status_code',
    'user_agent': 'http_user_agent',
    'orig_mime_types': 'http_orig_mime_types',
    'resp_mime_types': 'http_resp_mime_types'
}

new_weird_column_names = {
    'name': 'weird_name',
    'addl': 'weird_addl',
    'notice': 'weird_notice'
}

for i in range(1, 13):
    ddos_conn_df[i]  = ddos_conn_df[i].rename(columns=new_conn_column_names)
    ddos_conn_df[i]  = ddos_conn_df[i].rename(columns=new_statics_column_names)
    ddos_dns_fs[i]   = ddos_dns_fs[i].rename(columns=new_dns_column_names)
    ddos_ssl_fs[i]   = ddos_ssl_fs[i].rename(columns=new_ssl_column_names)
    ddos_http_fs[i]  = ddos_http_fs[i].rename(columns=new_http_column_names)
    ddos_weird_fs[i] = ddos_weird_fs[i].rename(columns=new_weird_column_names)

# %%
# backdoor

new_conn_column_names = {
    'id.orig_h': 'src_ip',
    'id.orig_p': 'src_port',
    'id.resp_h': 'dst_ip',
    'id.resp_p': 'dst_port',
    'orig_bytes': 'src_bytes',
    'resp_bytes': 'dst_bytes'
}

new_statics_column_names = {
    'orig_pkts': 'src_pkts',
    'resp_pkts': 'dst_pkts',
    'orig_ip_bytes': 'src_ip_bytes',
    'resp_ip_bytes': 'dst_ip_bytes'
}

new_dns_column_names = {
    'query': 'dns_query',
    'qclass': 'dns_qclass',
    'qtype': 'dns_qtype',
    'rcode': 'dns_rcode',
    'AA': 'dns_AA',
    'RD': 'dns_RD',
    'RA': 'dns_RA',
    'rejected': 'dns_rejected'
}

new_ssl_column_names = {
    'version': 'ssl_version',
    'cipher': 'ssl_cipher',
    'resumed': 'ssl_resumed',
    'established': 'ssl_established',
    'subject': 'ssl_subject',
    'issuer': 'ssl_issuer'
}

new_http_column_names = {
    'trans_depth': 'http_trans_depth',
    'method': 'http_method',
    'uri': 'http_uri',
    'referrer': 'http_referrer',
    'version': 'http_version',
    'request_body_len': 'http_request_body_len',
    'response_body_len': 'http_response_body_len',
    'status_code': 'http_status_code',
    'user_agent': 'http_user_agent',
    'orig_mime_types': 'http_orig_mime_types',
    'resp_mime_types': 'http_resp_mime_types'
}

new_weird_column_names = {
    'name': 'weird_name',
    'addl': 'weird_addl',
    'notice': 'weird_notice'
}

backdoor_conn_df  = backdoor_conn_df.rename(columns=new_conn_column_names)
backdoor_conn_df  = backdoor_conn_df.rename(columns=new_statics_column_names)
backdoor_dns_fs   = backdoor_dns_fs.rename(columns=new_dns_column_names)
backdoor_ssl_fs   = backdoor_ssl_fs.rename(columns=new_ssl_column_names)
backdoor_http_fs  = backdoor_http_fs.rename(columns=new_http_column_names)
backdoor_weird_fs = backdoor_weird_fs.rename(columns=new_weird_column_names)

# %%
# password

new_conn_column_names = {
    'id.orig_h': 'src_ip',
    'id.orig_p': 'src_port',
    'id.resp_h': 'dst_ip',
    'id.resp_p': 'dst_port',
    'orig_bytes': 'src_bytes',
    'resp_bytes': 'dst_bytes'
}

new_statics_column_names = {
    'orig_pkts': 'src_pkts',
    'resp_pkts': 'dst_pkts',
    'orig_ip_bytes': 'src_ip_bytes',
    'resp_ip_bytes': 'dst_ip_bytes'
}

new_dns_column_names = {
    'query': 'dns_query',
    'qclass': 'dns_qclass',
    'qtype': 'dns_qtype',
    'rcode': 'dns_rcode',
    'AA': 'dns_AA',
    'RD': 'dns_RD',
    'RA': 'dns_RA',
    'rejected': 'dns_rejected'
}

new_ssl_column_names = {
    'version': 'ssl_version',
    'cipher': 'ssl_cipher',
    'resumed': 'ssl_resumed',
    'established': 'ssl_established',
    'subject': 'ssl_subject',
    'issuer': 'ssl_issuer'
}

new_http_column_names = {
    'trans_depth': 'http_trans_depth',
    'method': 'http_method',
    'uri': 'http_uri',
    'referrer': 'http_referrer',
    'version': 'http_version',
    'request_body_len': 'http_request_body_len',
    'response_body_len': 'http_response_body_len',
    'status_code': 'http_status_code',
    'user_agent': 'http_user_agent',
    'orig_mime_types': 'http_orig_mime_types',
    'resp_mime_types': 'http_resp_mime_types'
}

new_weird_column_names = {
    'name': 'weird_name',
    'addl': 'weird_addl',
    'notice': 'weird_notice'
}

for i in range(1, 6):
    password_conn_df[i]  = password_conn_df[i].rename(columns=new_conn_column_names)
    password_conn_df[i]  = password_conn_df[i].rename(columns=new_statics_column_names)
    password_dns_fs[i]   = password_dns_fs[i].rename(columns=new_dns_column_names)
    password_ssl_fs[i]   = password_ssl_fs[i].rename(columns=new_ssl_column_names)
    password_http_fs[i]  = password_http_fs[i].rename(columns=new_http_column_names)
    password_weird_fs[i] = password_weird_fs[i].rename(columns=new_weird_column_names)

# %%
# ransomware

new_conn_column_names = {
    'id.orig_h': 'src_ip',
    'id.orig_p': 'src_port',
    'id.resp_h': 'dst_ip',
    'id.resp_p': 'dst_port',
    'orig_bytes': 'src_bytes',
    'resp_bytes': 'dst_bytes'
}

new_statics_column_names = {
    'orig_pkts': 'src_pkts',
    'resp_pkts': 'dst_pkts',
    'orig_ip_bytes': 'src_ip_bytes',
    'resp_ip_bytes': 'dst_ip_bytes'
}

new_dns_column_names = {
    'query': 'dns_query',
    'qclass': 'dns_qclass',
    'qtype': 'dns_qtype',
    'rcode': 'dns_rcode',
    'AA': 'dns_AA',
    'RD': 'dns_RD',
    'RA': 'dns_RA',
    'rejected': 'dns_rejected'
}

new_ssl_column_names = {
    'version': 'ssl_version',
    'cipher': 'ssl_cipher',
    'resumed': 'ssl_resumed',
    'established': 'ssl_established',
    'subject': 'ssl_subject',
    'issuer': 'ssl_issuer'
}

new_http_column_names = {
    'trans_depth': 'http_trans_depth',
    'method': 'http_method',
    'uri': 'http_uri',
    'referrer': 'http_referrer',
    'version': 'http_version',
    'request_body_len': 'http_request_body_len',
    'response_body_len': 'http_response_body_len',
    'status_code': 'http_status_code',
    'user_agent': 'http_user_agent',
    'orig_mime_types': 'http_orig_mime_types',
    'resp_mime_types': 'http_resp_mime_types'
}

new_weird_column_names = {
    'name': 'weird_name',
    'addl': 'weird_addl',
    'notice': 'weird_notice'
}

ransomware_conn_df  = ransomware_conn_df.rename(columns=new_conn_column_names)
ransomware_conn_df  = ransomware_conn_df.rename(columns=new_statics_column_names)
ransomware_dns_fs   = ransomware_dns_fs.rename(columns=new_dns_column_names)
ransomware_ssl_fs   = ransomware_ssl_fs.rename(columns=new_ssl_column_names)
ransomware_http_fs  = ransomware_http_fs.rename(columns=new_http_column_names)
ransomware_weird_fs = ransomware_weird_fs.rename(columns=new_weird_column_names)

# %%
# injection

new_conn_column_names = {
    'id.orig_h': 'src_ip',
    'id.orig_p': 'src_port',
    'id.resp_h': 'dst_ip',
    'id.resp_p': 'dst_port',
    'orig_bytes': 'src_bytes',
    'resp_bytes': 'dst_bytes'
}

new_statics_column_names = {
    'orig_pkts': 'src_pkts',
    'resp_pkts': 'dst_pkts',
    'orig_ip_bytes': 'src_ip_bytes',
    'resp_ip_bytes': 'dst_ip_bytes'
}

new_dns_column_names = {
    'query': 'dns_query',
    'qclass': 'dns_qclass',
    'qtype': 'dns_qtype',
    'rcode': 'dns_rcode',
    'AA': 'dns_AA',
    'RD': 'dns_RD',
    'RA': 'dns_RA',
    'rejected': 'dns_rejected'
}

new_ssl_column_names = {
    'version': 'ssl_version',
    'cipher': 'ssl_cipher',
    'resumed': 'ssl_resumed',
    'established': 'ssl_established',
    'subject': 'ssl_subject',
    'issuer': 'ssl_issuer'
}

new_http_column_names = {
    'trans_depth': 'http_trans_depth',
    'method': 'http_method',
    'uri': 'http_uri',
    'referrer': 'http_referrer',
    'version': 'http_version',
    'request_body_len': 'http_request_body_len',
    'response_body_len': 'http_response_body_len',
    'status_code': 'http_status_code',
    'user_agent': 'http_user_agent',
    'orig_mime_types': 'http_orig_mime_types',
    'resp_mime_types': 'http_resp_mime_types'
}

new_weird_column_names = {
    'name': 'weird_name',
    'addl': 'weird_addl',
    'notice': 'weird_notice'
}

for i in range(1, 5):
    injection_conn_df[i]  = injection_conn_df[i].rename(columns=new_conn_column_names)
    injection_conn_df[i]  = injection_conn_df[i].rename(columns=new_statics_column_names)
    injection_dns_fs[i]   = injection_dns_fs[i].rename(columns=new_dns_column_names)
    injection_ssl_fs[i]   = injection_ssl_fs[i].rename(columns=new_ssl_column_names)
    injection_http_fs[i]  = injection_http_fs[i].rename(columns=new_http_column_names)
    injection_weird_fs[i] = injection_weird_fs[i].rename(columns=new_weird_column_names)

# %%
# scanning

new_conn_column_names = {
    'id.orig_h': 'src_ip',
    'id.orig_p': 'src_port',
    'id.resp_h': 'dst_ip',
    'id.resp_p': 'dst_port',
    'orig_bytes': 'src_bytes',
    'resp_bytes': 'dst_bytes'
}

new_statics_column_names = {
    'orig_pkts': 'src_pkts',
    'resp_pkts': 'dst_pkts',
    'orig_ip_bytes': 'src_ip_bytes',
    'resp_ip_bytes': 'dst_ip_bytes'
}

new_dns_column_names = {
    'query': 'dns_query',
    'qclass': 'dns_qclass',
    'qtype': 'dns_qtype',
    'rcode': 'dns_rcode',
    'AA': 'dns_AA',
    'RD': 'dns_RD',
    'RA': 'dns_RA',
    'rejected': 'dns_rejected'
}

new_ssl_column_names = {
    'version': 'ssl_version',
    'cipher': 'ssl_cipher',
    'resumed': 'ssl_resumed',
    'established': 'ssl_established',
    'subject': 'ssl_subject',
    'issuer': 'ssl_issuer'
}

new_http_column_names = {
    'trans_depth': 'http_trans_depth',
    'method': 'http_method',
    'uri': 'http_uri',
    'referrer': 'http_referrer',
    'version': 'http_version',
    'request_body_len': 'http_request_body_len',
    'response_body_len': 'http_response_body_len',
    'status_code': 'http_status_code',
    'user_agent': 'http_user_agent',
    'orig_mime_types': 'http_orig_mime_types',
    'resp_mime_types': 'http_resp_mime_types'
}

new_weird_column_names = {
    'name': 'weird_name',
    'addl': 'weird_addl',
    'notice': 'weird_notice'
}

for i in range(1, 7):
    scanning_conn_df[i]  = scanning_conn_df[i].rename(columns=new_conn_column_names)
    scanning_conn_df[i]  = scanning_conn_df[i].rename(columns=new_statics_column_names)
    scanning_dns_fs[i]   = scanning_dns_fs[i].rename(columns=new_dns_column_names)
    scanning_ssl_fs[i]   = scanning_ssl_fs[i].rename(columns=new_ssl_column_names)
    scanning_http_fs[i]  = scanning_http_fs[i].rename(columns=new_http_column_names)
    scanning_weird_fs[i] = scanning_weird_fs[i].rename(columns=new_weird_column_names)

# %%
# dos

new_conn_column_names = {
    'id.orig_h': 'src_ip',
    'id.orig_p': 'src_port',
    'id.resp_h': 'dst_ip',
    'id.resp_p': 'dst_port',
    'orig_bytes': 'src_bytes',
    'resp_bytes': 'dst_bytes'
}

new_statics_column_names = {
    'orig_pkts': 'src_pkts',
    'resp_pkts': 'dst_pkts',
    'orig_ip_bytes': 'src_ip_bytes',
    'resp_ip_bytes': 'dst_ip_bytes'
}

new_dns_column_names = {
    'query': 'dns_query',
    'qclass': 'dns_qclass',
    'qtype': 'dns_qtype',
    'rcode': 'dns_rcode',
    'AA': 'dns_AA',
    'RD': 'dns_RD',
    'RA': 'dns_RA',
    'rejected': 'dns_rejected'
}

new_ssl_column_names = {
    'version': 'ssl_version',
    'cipher': 'ssl_cipher',
    'resumed': 'ssl_resumed',
    'established': 'ssl_established',
    'subject': 'ssl_subject',
    'issuer': 'ssl_issuer'
}

new_http_column_names = {
    'trans_depth': 'http_trans_depth',
    'method': 'http_method',
    'uri': 'http_uri',
    'referrer': 'http_referrer',
    'version': 'http_version',
    'request_body_len': 'http_request_body_len',
    'response_body_len': 'http_response_body_len',
    'status_code': 'http_status_code',
    'user_agent': 'http_user_agent',
    'orig_mime_types': 'http_orig_mime_types',
    'resp_mime_types': 'http_resp_mime_types'
}

new_weird_column_names = {
    'name': 'weird_name',
    'addl': 'weird_addl',
    'notice': 'weird_notice'
}

for i in range(1, 6):
    dos_conn_df[i]  = dos_conn_df[i].rename(columns=new_conn_column_names)
    dos_conn_df[i]  = dos_conn_df[i].rename(columns=new_statics_column_names)
    dos_dns_fs[i]   = dos_dns_fs[i].rename(columns=new_dns_column_names)
    dos_ssl_fs[i]   = dos_ssl_fs[i].rename(columns=new_ssl_column_names)
    dos_http_fs[i]  = dos_http_fs[i].rename(columns=new_http_column_names)
    dos_weird_fs[i] = dos_weird_fs[i].rename(columns=new_weird_column_names)

# %%
# mitm

new_conn_column_names = {
    'id.orig_h': 'src_ip',
    'id.orig_p': 'src_port',
    'id.resp_h': 'dst_ip',
    'id.resp_p': 'dst_port',
    'orig_bytes': 'src_bytes',
    'resp_bytes': 'dst_bytes'
}

new_statics_column_names = {
    'orig_pkts': 'src_pkts',
    'resp_pkts': 'dst_pkts',
    'orig_ip_bytes': 'src_ip_bytes',
    'resp_ip_bytes': 'dst_ip_bytes'
}

new_dns_column_names = {
    'query': 'dns_query',
    'qclass': 'dns_qclass',
    'qtype': 'dns_qtype',
    'rcode': 'dns_rcode',
    'AA': 'dns_AA',
    'RD': 'dns_RD',
    'RA': 'dns_RA',
    'rejected': 'dns_rejected'
}

new_ssl_column_names = {
    'version': 'ssl_version',
    'cipher': 'ssl_cipher',
    'resumed': 'ssl_resumed',
    'established': 'ssl_established',
    'subject': 'ssl_subject',
    'issuer': 'ssl_issuer'
}

new_http_column_names = {
    'trans_depth': 'http_trans_depth',
    'method': 'http_method',
    'uri': 'http_uri',
    'referrer': 'http_referrer',
    'version': 'http_version',
    'request_body_len': 'http_request_body_len',
    'response_body_len': 'http_response_body_len',
    'status_code': 'http_status_code',
    'user_agent': 'http_user_agent',
    'orig_mime_types': 'http_orig_mime_types',
    'resp_mime_types': 'http_resp_mime_types'
}

new_weird_column_names = {
    'name': 'weird_name',
    'addl': 'weird_addl',
    'notice': 'weird_notice'
}

for i in range(1, 5):
    mitm_conn_df[i]  = mitm_conn_df[i].rename(columns=new_conn_column_names)
    mitm_conn_df[i]  = mitm_conn_df[i].rename(columns=new_statics_column_names)
    mitm_dns_fs[i]   = mitm_dns_fs[i].rename(columns=new_dns_column_names)
    mitm_ssl_fs[i]   = mitm_ssl_fs[i].rename(columns=new_ssl_column_names)
    mitm_http_fs[i]  = mitm_http_fs[i].rename(columns=new_http_column_names)
    mitm_weird_fs[i] = mitm_weird_fs[i].rename(columns=new_weird_column_names)

# %%
# xss

new_conn_column_names = {
    'id.orig_h': 'src_ip',
    'id.orig_p': 'src_port',
    'id.resp_h': 'dst_ip',
    'id.resp_p': 'dst_port',
    'orig_bytes': 'src_bytes',
    'resp_bytes': 'dst_bytes'
}

new_statics_column_names = {
    'orig_pkts': 'src_pkts',
    'resp_pkts': 'dst_pkts',
    'orig_ip_bytes': 'src_ip_bytes',
    'resp_ip_bytes': 'dst_ip_bytes'
}

new_dns_column_names = {
    'query': 'dns_query',
    'qclass': 'dns_qclass',
    'qtype': 'dns_qtype',
    'rcode': 'dns_rcode',
    'AA': 'dns_AA',
    'RD': 'dns_RD',
    'RA': 'dns_RA',
    'rejected': 'dns_rejected'
}

new_ssl_column_names = {
    'version': 'ssl_version',
    'cipher': 'ssl_cipher',
    'resumed': 'ssl_resumed',
    'established': 'ssl_established',
    'subject': 'ssl_subject',
    'issuer': 'ssl_issuer'
}

new_http_column_names = {
    'trans_depth': 'http_trans_depth',
    'method': 'http_method',
    'uri': 'http_uri',
    'referrer': 'http_referrer',
    'version': 'http_version',
    'request_body_len': 'http_request_body_len',
    'response_body_len': 'http_response_body_len',
    'status_code': 'http_status_code',
    'user_agent': 'http_user_agent',
    'orig_mime_types': 'http_orig_mime_types',
    'resp_mime_types': 'http_resp_mime_types'
}

new_weird_column_names = {
    'name': 'weird_name',
    'addl': 'weird_addl',
    'notice': 'weird_notice'
}

for i in range(1, 11):
    xss_conn_df[i]  = xss_conn_df[i].rename(columns=new_conn_column_names)
    xss_conn_df[i]  = xss_conn_df[i].rename(columns=new_statics_column_names)
    xss_dns_fs[i]   = xss_dns_fs[i].rename(columns=new_dns_column_names)
    xss_ssl_fs[i]   = xss_ssl_fs[i].rename(columns=new_ssl_column_names)
    xss_http_fs[i]  = xss_http_fs[i].rename(columns=new_http_column_names)
    xss_weird_fs[i] = xss_weird_fs[i].rename(columns=new_weird_column_names)

# %%
# normal

new_conn_column_names = {
    'id.orig_h': 'src_ip',
    'id.orig_p': 'src_port',
    'id.resp_h': 'dst_ip',
    'id.resp_p': 'dst_port',
    'orig_bytes': 'src_bytes',
    'resp_bytes': 'dst_bytes'
}

new_statics_column_names = {
    'orig_pkts': 'src_pkts',
    'resp_pkts': 'dst_pkts',
    'orig_ip_bytes': 'src_ip_bytes',
    'resp_ip_bytes': 'dst_ip_bytes'
}

new_dns_column_names = {
    'query': 'dns_query',
    'qclass': 'dns_qclass',
    'qtype': 'dns_qtype',
    'rcode': 'dns_rcode',
    'AA': 'dns_AA',
    'RD': 'dns_RD',
    'RA': 'dns_RA',
    'rejected': 'dns_rejected'
}

new_ssl_column_names = {
    'version': 'ssl_version',
    'cipher': 'ssl_cipher',
    'resumed': 'ssl_resumed',
    'established': 'ssl_established',
    'subject': 'ssl_subject',
    'issuer': 'ssl_issuer'
}

new_http_column_names = {
    'trans_depth': 'http_trans_depth',
    'method': 'http_method',
    'uri': 'http_uri',
    'referrer': 'http_referrer',
    'version': 'http_version',
    'request_body_len': 'http_request_body_len',
    'response_body_len': 'http_response_body_len',
    'status_code': 'http_status_code',
    'user_agent': 'http_user_agent',
    'orig_mime_types': 'http_orig_mime_types',
    'resp_mime_types': 'http_resp_mime_types'
}

new_weird_column_names = {
    'name': 'weird_name',
    'addl': 'weird_addl',
    'notice': 'weird_notice'
}

for i in range(1, 16):
    normal_conn_df[i]  = normal_conn_df[i].rename(columns=new_conn_column_names)
    normal_conn_df[i]  = normal_conn_df[i].rename(columns=new_statics_column_names)
    normal_dns_fs[i]   = normal_dns_fs[i].rename(columns=new_dns_column_names)
    normal_ssl_fs[i]   = normal_ssl_fs[i].rename(columns=new_ssl_column_names)
    normal_http_fs[i]  = normal_http_fs[i].rename(columns=new_http_column_names)
    normal_weird_fs[i] = normal_weird_fs[i].rename(columns=new_weird_column_names)

# %% [markdown]
# # <center> mergeing and feature selection </center>

# %%
# ddos

ddos_raw_df = {}

for i in range(1, 13):
    ddos_raw_df[i] = ddos_conn_df[i].merge(ddos_dns_fs[i], on="uid", how="left")
    ddos_raw_df[i] = ddos_raw_df[i].merge(ddos_http_fs[i], on="uid", how="left")
    ddos_raw_df[i] = ddos_raw_df[i].merge(ddos_ssl_fs[i], on="uid", how="left") 
    ddos_raw_df[i] = ddos_raw_df[i].merge(ddos_weird_fs[i], on="uid", how="left")
    ddos_raw_df[i] = ddos_raw_df[i].drop(columns=["uid", "tunnel_parents", "local_orig", "local_resp", "history"])

# %%
# backdoor

backdoor_raw_df = backdoor_conn_df.merge(backdoor_dns_fs, on="uid", how="left")
backdoor_raw_df = backdoor_raw_df.merge(backdoor_http_fs, on="uid", how="left")
backdoor_raw_df = backdoor_raw_df.merge(backdoor_ssl_fs, on="uid", how="left") 
backdoor_raw_df = backdoor_raw_df.merge(backdoor_weird_fs, on="uid", how="left")
backdoor_raw_df = backdoor_raw_df.drop(columns=["uid", "tunnel_parents", "local_orig", "local_resp", "history"])

# %%
# password

password_raw_df = {}

for i in range(1, 6):
    password_raw_df[i] = password_conn_df[i].merge(password_dns_fs[i], on="uid", how="left")
    password_raw_df[i] = password_raw_df[i].merge(password_http_fs[i], on="uid", how="left")
    password_raw_df[i] = password_raw_df[i].merge(password_ssl_fs[i], on="uid", how="left") 
    password_raw_df[i] = password_raw_df[i].merge(password_weird_fs[i], on="uid", how="left")
    password_raw_df[i] = password_raw_df[i].drop(columns=["uid", "tunnel_parents", "local_orig", "local_resp", "history"])

# merging can cause some rows to be duplicated

# %%
# ransomware

ransomware_raw_df = ransomware_conn_df.merge(ransomware_dns_fs, on="uid", how="left")
ransomware_raw_df = ransomware_raw_df.merge(ransomware_http_fs, on="uid", how="left")
ransomware_raw_df = ransomware_raw_df.merge(ransomware_ssl_fs, on="uid", how="left") 
ransomware_raw_df = ransomware_raw_df.merge(ransomware_weird_fs, on="uid", how="left")
ransomware_raw_df = ransomware_raw_df.drop(columns=["uid", "tunnel_parents", "local_orig", "local_resp", "history"])

# %%
# injection

injection_raw_df = {}

for i in range(1, 5):
    injection_raw_df[i] = injection_conn_df[i].merge(injection_dns_fs[i], on="uid", how="left")
    injection_raw_df[i] = injection_raw_df[i].merge(injection_http_fs[i], on="uid", how="left")
    injection_raw_df[i] = injection_raw_df[i].merge(injection_ssl_fs[i], on="uid", how="left") 
    injection_raw_df[i] = injection_raw_df[i].merge(injection_weird_fs[i], on="uid", how="left")
    injection_raw_df[i] = injection_raw_df[i].drop(columns=["uid", "tunnel_parents", "local_orig", "local_resp", "history"])

# %%
# scanning

scanning_raw_df = {}

for i in range(1, 7):
    scanning_raw_df[i] = scanning_conn_df[i].merge(scanning_dns_fs[i], on="uid", how="left")
    scanning_raw_df[i] = scanning_raw_df[i].merge(scanning_http_fs[i], on="uid", how="left")
    scanning_raw_df[i] = scanning_raw_df[i].merge(scanning_ssl_fs[i], on="uid", how="left") 
    scanning_raw_df[i] = scanning_raw_df[i].merge(scanning_weird_fs[i], on="uid", how="left")
    scanning_raw_df[i] = scanning_raw_df[i].drop(columns=["uid", "tunnel_parents", "local_orig", "local_resp", "history"])

# %%
# dos

dos_raw_df = {}

for i in range(1, 6):
    dos_raw_df[i] = dos_conn_df[i].merge(dos_dns_fs[i], on="uid", how="left")
    dos_raw_df[i] = dos_raw_df[i].merge(dos_http_fs[i], on="uid", how="left")
    dos_raw_df[i] = dos_raw_df[i].merge(dos_ssl_fs[i], on="uid", how="left") 
    dos_raw_df[i] = dos_raw_df[i].merge(dos_weird_fs[i], on="uid", how="left")
    dos_raw_df[i] = dos_raw_df[i].drop(columns=["uid", "tunnel_parents", "local_orig", "local_resp", "history"])

# %%
# mitm

mitm_raw_df = {}

for i in range(1, 5):
    mitm_raw_df[i] = mitm_conn_df[i].merge(mitm_dns_fs[i], on="uid", how="left")
    mitm_raw_df[i] = mitm_raw_df[i].merge(mitm_http_fs[i], on="uid", how="left")
    mitm_raw_df[i] = mitm_raw_df[i].merge(mitm_ssl_fs[i], on="uid", how="left") 
    mitm_raw_df[i] = mitm_raw_df[i].merge(mitm_weird_fs[i], on="uid", how="left")
    mitm_raw_df[i] = mitm_raw_df[i].drop(columns=["uid", "tunnel_parents", "local_orig", "local_resp", "history"])

# %%
# xss

xss_raw_df = {}

for i in range(1, 11):
    xss_raw_df[i] = xss_conn_df[i].merge(xss_dns_fs[i], on="uid", how="left")
    xss_raw_df[i] = xss_raw_df[i].merge(xss_http_fs[i], on="uid", how="left")
    xss_raw_df[i] = xss_raw_df[i].merge(xss_ssl_fs[i], on="uid", how="left") 
    xss_raw_df[i] = xss_raw_df[i].merge(xss_weird_fs[i], on="uid", how="left")
    xss_raw_df[i] = xss_raw_df[i].drop(columns=["uid", "tunnel_parents", "local_orig", "local_resp", "history"])

# %%
# normal

normal_raw_df = {}

for i in range(1, 16):
    normal_raw_df[i] = normal_conn_df[i].merge(normal_dns_fs[i], on="uid", how="left")
    normal_raw_df[i] = normal_raw_df[i].merge(normal_http_fs[i], on="uid", how="left")
    normal_raw_df[i] = normal_raw_df[i].merge(normal_ssl_fs[i], on="uid", how="left") 
    normal_raw_df[i] = normal_raw_df[i].merge(normal_weird_fs[i], on="uid", how="left")
    normal_raw_df[i] = normal_raw_df[i].drop(columns=["uid", "tunnel_parents", "local_orig", "local_resp", "history"])

# %% [markdown]
# # <center> create raw_df </center>

# %%
# ddos

ddos_raw_df = pd.concat([ddos_raw_df[i] for i in range(1, 13)], ignore_index=True)

# %%
# password

password_raw_df = pd.concat([password_raw_df[i] for i in range(1, 6)], ignore_index=True)

# %%
# injection

injection_raw_df = pd.concat([injection_raw_df[i] for i in range(1, 5)], ignore_index=True)

# %%
# scanning

scanning_raw_df = pd.concat([scanning_raw_df[i] for i in range(1, 7)], ignore_index=True)

# %%
# dos

dos_raw_df = pd.concat([dos_raw_df[i] for i in range(1, 6)], ignore_index=True)

# %%
# mitm

mitm_raw_df = pd.concat([mitm_raw_df[i] for i in range(1, 5)], ignore_index=True)

# %%
# xss

xss_raw_df = pd.concat([xss_raw_df[i] for i in range(1, 11)], ignore_index=True) # ignore index true means that the index will be reset

# %%
# normal

normal_raw_df = pd.concat([normal_raw_df[i] for i in range(1, 16)], ignore_index=True)

# %% [markdown]
# # <center> save </center>

# %%
# ddos

ddos_raw_df.to_csv("your-path\\normal-attack\\csv-2\\ddos.csv", index=False)

# %%
# backdoor

backdoor_raw_df.to_csv("your-path\\normal-attack\\csv-2\\backdoor.csv", index=False)

# %%
# password

password_raw_df.to_csv("your-path\\normal-attack\\csv-2\\password.csv", index=False)

# %%
# ransomware

ransomware_raw_df.to_csv("your-path\\normal-attack\\csv-2\\ransomware.csv", index=False)

# %%
# injection

injection_raw_df.to_csv("your-path\\normal-attack\\csv-2\\injection.csv", index=False)

# %%
# scanning

scanning_raw_df.to_csv("your-path\\normal-attack\\csv-2\\scanning.csv", index=False)

# %%
# dos

dos_raw_df.to_csv("your-path\\normal-attack\\csv-2\\dos.csv", index=False)

# %%
# mitm

mitm_raw_df.to_csv("your-path\\normal-attack\\csv-2\\mitm.csv", index=False)

# %%
# xss

xss_raw_df.to_csv("your-path\\normal-attack\\csv-2\\xss.csv", index=False) # index false means that the index will not be saved

# %%
# normal

normal_raw_df.to_csv("your-path\\normal\\csv-2\\normal.csv", index=False)
